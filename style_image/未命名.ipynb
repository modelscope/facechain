# %%
# !python3 app.py
# Out:
# 2023-09-13 00:38:38,477 - modelscope - INFO - PyTorch version 2.0.1+cu118 Found.
# 2023-09-13 00:38:38,481 - modelscope - INFO - TensorFlow version 2.13.0 Found.
# 2023-09-13 00:38:38,481 - modelscope - INFO - Loading ast index from /mnt/workspace/.cache/modelscope/ast_indexer
# 2023-09-13 00:38:38,504 - modelscope - INFO - Loading done! Current index file version is 1.9.0, with md5 e024469f80e1732f2cfc5efd837ca7df and a total number of 921 components indexed
# /opt/conda/lib/python3.8/site-packages/controlnet_aux/mediapipe_face/mediapipe_face_common.py:7: UserWarning: The module 'mediapipe' is not installed. The package will have limited functionality. Please install it using the command: pip install 'mediapipe'
#   warnings.warn(
# [2023-09-13 00:38:39,750] [INFO] [real_accelerator.py:158:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# ...
